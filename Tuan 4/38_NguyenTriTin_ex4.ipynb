# %% [markdown]
# ## BÀI TẬP

# %%
# Import các thư viện thông dụng
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import các distribution packages từ thư viện scipy
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import t

# %% [markdown]
# **Bài 01:** Một bài thi trắc nghiệm gồm 10 câu hỏi, mỗi câu có 4 phương án trả lời trong đó chỉ có một phương án đúng. Bạn hãy:
#
# a. Một sinh viên không học bài làm bài bằng cách chọn ngẫu nhiên một phương án cho mỗi câu hỏi. Bạn hãy dùng hàm random để in ra số câu đúng của bạn sinh viên trong 10 lần kiểm tra.
#
# b. Giả sử mỗi câu đúng được 4 điểm, mỗi câu sai bị trừ 2 điểm. Tính xác suất để sinh viên này được 4 điểm
#
# c. Gọi X là số câu trả lời đúng. Tính E(X) và Var(X)

# %%
#Câu a
x = binom.rvs(10,0.25, size=10)
print('Kết quả sau 10 lần kiểm tra là: ')
print(x)

#Câu c
print(f'E(X) = ',np.mean(x))
print(f'Var(X) = ',np.var(x, ddof=1))
# Out:
# Kết quả sau 10 lần kiểm tra là:
# [4 4 3 3 2 2 4 2 3 1]
# E(X) =  2.8
# Var(X) =  1.0666666666666667

# %% [markdown]
# **Bài 02:** Một trung tâm bưu điện nhận được 3 cuộc gọi điện thoại mỗi phút. Tính xác suất để trung tâm nhận được 1 cuộc gọi, 2 cuộc gọi, 3 cuộc gọi trong vòng một phút biết số cuộc gọi trong một phút có phân phối Poisson.

# %%
for i in range (0,11):
    p = poisson.pmf(i, 3)
    print(f'x=',i,', f(',i,')=', p)
# Out:
# x= 0 , f( 0 )= 0.049787068367863944
# x= 1 , f( 1 )= 0.14936120510359185
# x= 2 , f( 2 )= 0.22404180765538775
# x= 3 , f( 3 )= 0.22404180765538775
# x= 4 , f( 4 )= 0.16803135574154085
# x= 5 , f( 5 )= 0.10081881344492458
# x= 6 , f( 6 )= 0.05040940672246224
# x= 7 , f( 7 )= 0.02160403145248382
# x= 8 , f( 8 )= 0.008101511794681432
# x= 9 , f( 9 )= 0.002700503931560479
# x= 10 , f( 10 )= 0.0008101511794681439

# %% [markdown]
# **Bài 03:** Trọng lượng (đơn vị gam) của một loại trái cây có phân phối chuẩn với µ = 500 (gam) gam và $σ^2 = 16 (gam^2)$. Trái cây thu hoạch được phân loại theo trọng lượng như sau:
#
# Loại 1: trên 505 gam
#
# Loại 2: từ 495 – 505 gam
#
# Loại 3: dười 495 gam
#
# a. Hãy tính tỷ lệ của mỗi loại.
#
# b. Bạn hãy mô phỏng lấy mẫu  20 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
#
# c. Bạn hãy mô phỏng lấy 100 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
#
# d. Từ hai cách lấy mẫu ở câu b, c bạn có nhận xét gì không?

# %%
#Câu a
mu, sigma = 500, 4
tyLe1=1-norm.cdf(505, mu, sigma)
tyLe3=1-norm.cdf(495, mu, sigma)
print(f'Tỷ lệ của loại 1:', tyLe1)
print(f'Tỷ lệ của loại 2:', tyLe3-tyLe1)
print(f'Tỷ lệ của loại 3:', tyLe3)

#Câu b
print('Lấy mẫu 20')
sample_20 = np.random.normal(mu, sigma, 20)
print(sample_20)
plt.figure(figsize= (10,5))
plt.hist(sample_20)
plt.xlabel('Trọng lượng')
plt.ylabel('Số lượng')
plt.title('Lấy mẫu 20')
print(f'Giá trị trung bình của 20 mẫu là:', np.mean(sample_20))
print(f'Độ lệch chuẩn của 20 mẫu là:', np.std(sample_20))

#Câu c
print('Lấy mẫu 100')
sample_100 = np.random.normal(mu, sigma, 100)
print(sample_100)
plt.figure(figsize=(10,5))
plt.hist(sample_100)
plt.xlabel('Trọng lượng')
plt.ylabel('Số lượng')
plt.title('Lấy mẫu 100')
print(f'Giá trị trung bình của 100 mẫu là:', np.mean(sample_100))
print(f'Độ lệch chuẩn của 100 mẫu là:', np.std(sample_100))
# Out:
# Tỷ lệ của loại 1: 0.10564977366685535
# Tỷ lệ của loại 2: 0.7887004526662893
# Tỷ lệ của loại 3: 0.8943502263331446
# Lấy mẫu 20
# [504.64085684 500.22806705 499.84467381 500.58413658 498.41813613
#  499.0892508  508.41105265 503.79407842 502.69096033 498.57137817
#  495.86898128 501.23201847 509.11371559 496.06878785 505.31048787
#  498.05224125 502.11768918 503.11607504 494.89212029 506.58364141]
# Giá trị trung bình của 20 mẫu là: 501.43141744984905
# Độ lệch chuẩn của 20 mẫu là: 3.9462158165818466
# Lấy mẫu 100
# [499.35190682 503.38528446 496.35362489 491.82539906 500.93789371
#  499.56704221 494.85025654 497.00829526 496.19157761 487.97876574
#  497.63232191 497.42801824 503.10470593 495.94023298 497.74256916
#  504.35955102 497.73207586 503.180339   500.57931919 504.02788975
#  501.20319101 497.94409884 499.50198835 503.20377264 508.37360996
#  502.25968611 504.91111684 504.53647453 501.09365647 502.07419971
#  505.7037985  497.71941185 503.12661398 494.70848297 503.18115682
#  502.72148875 492.60152444 499.62049664 501.28176461 500.64675054
#  503.24268844 500.05001327 504.78720469 497.05373005 504.40440076
#  497.96180221 500.97359841 504.03927917 502.34518527 502.80818677
#  499.18989215 499.37724663 493.58295145 496.52008655 493.4409644
#  499.82784917 496.89593386 495.93157115 497.72031456 502.62670355
#  499.52690112 496.21089565 494.19504906 496.66770461 491.96130151
#  492.88360932 498.93182498 500.23767554 501.46051287 498.68775328
#  497.88236129 498.85516845 491.90105175 496.87083837 501.77574535
#  501.40510582 495.21642331 498.59625348 499.97990082 493.94896087
#  499.77405822 507.59741815 499.76630639 494.02683601 499.32156637
#  504.48090235 493.75900293 497.97883595 499.07809992 502.3400647
#  499.52306837 506.44079488 493.72538171 501.07135605 502.2738644
#  488.81573219 496.88973996 502.76671574 494.75907222 498.98433894]
# Giá trị trung bình của 100 mẫu là: 499.1893814828969
# Độ lệch chuẩn của 100 mẫu là: 3.9860619001728943

# %% [markdown]
# **Bài 04:** Mô phỏng tung một con xúc sắc cân đối đồng chất 5000 lần. Dựa vào giá trị mô phỏng, bạn hãy tìm các giá trị xác suất dưới đây:
#
# a. Xác suất để  số chấm xuất hiện là 4
#
# b. Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4
#
# c. Giả sử biết số chấm xuất hiện lớn hơn hoặc bằng 4. Hãy tìm xác suất để mặt 6 chấm xuất hiện.

# %%
x = np.random.randint(1, 7, 5000)
print(f'Xác suất để số chấm xuất hiện là 4:',np.mean(x == 4))

print(f'Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4:', np.mean(x >= 4))
diceRollGreaterEqual = x[x>=4]
print(f'Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4:',np.mean(diceRollGreaterEqual==6))
# Out:
# Xác suất để số chấm xuất hiện là 4: 0.1706
# Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4: 0.5046
# Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4: 0.33729686880697585

# %% [markdown]
# **Bài 05:** Tạo 5000 số ngẫu nhiên có phân phối nhị thức với n=50, p=0.7 Bạn Hãy
#
# a. Tìm các giá trị thống kê: min, max, Q1, Q2, Q3
#
# b. Vẽ đồ thị boxplot
#
# c. Vẽ các đồ thị: tần số, tần suất

# %%
x = binom.rvs(50, 0.7, size=5000)
print(x)
#Câu a
print(f'Số lớn nhất là: ', max(x))
print(f'Số nhỏ nhất là: ', min(x))
print(f'Q1: ', np.quantile(x, 0.25))
print(f'Q2: ', np.quantile(x, 0.5))
print(f'Q3: ', np.quantile(x, 0.75))

#Câu b
plt.figure(figsize=(10,5))
plt.boxplot(x)
plt.xlabel("Mẫu")
plt.ylabel("Giá trị")

# Câu c
plt.figure(figsize=(10, 5))

# Tần số
plt.subplot(1, 2, 1)
plt.hist(x, bins=20, edgecolor='black', alpha=0.7)
plt.title("Biểu đồ tần số")
plt.xlabel("Giá trị")
plt.ylabel("Tần số")

# Tần suất
plt.subplot(1, 2, 2)
plt.hist(x, bins=20, density=True, edgecolor='black', alpha=0.7)
plt.title("Biểu đồ tần suất")
plt.xlabel("Giá trị")
plt.ylabel("Tần suất")
# Out:
# [32 35 37 ... 39 33 31]
# Số lớn nhất là:  46
# Số nhỏ nhất là:  24
# Q1:  33.0
# Q2:  35.0
# Q3:  37.0
# Text(0, 0.5, 'Tần suất')
