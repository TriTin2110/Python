# %% [markdown]
# # Lab 03 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
import pandas as pd
import numpy as np
from numpy import random

arr = random.randint(1000, size=100)
print(arr)
print('-----------------------')
for i in range (0, 10):
        print(arr[i])
print('-----------------------')
for i in range(len(arr)-5, len(arr)):
        print(arr[i])
print('-----------------------')
for i in arr:
        if(i%5==0 and i >100):
                print(i)
# Out:
# [994 327 723 610 528 824  55 662 971 810 819 476 259 925 174 458 557 162
#  356 855 811 224 246 936 122 824 965 829 136 329 245 967 282  95 215  43
#  892  41 526 802 516 920 497 633 921 551 567  85 225 238 640 812 836 647
#  648 846 343 791 221 520 214 480 671 908 332 157 551 741 697 845 327 447
#  861 825 260 340 282 562  60 584 943 802 862 158 402 651 749 732 414 808
#  197 670 427 744 212 413 628 996 131 450]
# -----------------------
# 994
# 327
# 723
# 610
# 528
# 824
# 55
# 662
# 971
# 810
# -----------------------
# 413
# 628
# 996
# 131
# 450
# -----------------------
# 610
# 810
# 925
# 855
# 965
# 245
# 215
# 920
# 225
# 640
# 520
# 480
# 845
# 825
# 260
# 340
# 670
# 450

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
for i in arr:
        if(i<100):
                print(i)
# Out:
# 55
# 95
# 43
# 41
# 85
# 60

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print(f'Tổng mảng là:', arr.sum())
print(f'Giá trị trung bình:', np.mean(arr))
print(f'Giá trị trung vị:', np.median(arr))
print(f'Giá trị Q1, Q2, Q3:', np.quantile(arr, [0.25,0.5,0.75]))
print(f'Giá trị 20:', np.quantile(arr, 0.2))
# Out:
# Tổng mảng là: 54065
# Giá trị trung bình: 540.65
# Giá trị trung vị: 554.0
# Giá trị Q1, Q2, Q3: [276.5  554.   810.25]
# Giá trị 20: 235.4

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range (1,5):
        print(random.choice(arr, replace=False, size=10))
# Out:
# [ 60 996 855 356 640 824  95  43 965 340]
# [551 551 824 671 819 670 824 480 647 836]
# [812 562 158 516 528 557 497 551 343 920]
# [480 671 836 174 557 259 921 662 212 647]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
value, count = np.unique(arr, return_counts=True)
print(f'Phần tử xuất hiện nhiều nhất trong mảng là:', value[count.argmax()])
# Out:
# Phần tử xuất hiện nhiều nhất trong mảng là: 282

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# Your code here

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [2,4,1])
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# Your code here

# %%
plt.plot([10,20,30],[20,40,10], color='red', label='line 1')
plt.plot([10,20,30], [40,10,30], color='blue', label='line 2')
plt.title('Đồ thị hai đường thẳng')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# Your code here

# %%
plt.plot([1,4,5,6,7], [2,6,3,6,3], marker='o', mfc='orange', mec='red')
plt.title('Sử dụng marker')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# Your code here

# %%
x = np.linspace(0, np.pi*2)
plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x, np.cos(x), ls='--', label='cos(x)')
plt.title('Đồ thị hàm sin(x) và cos(x)')
plt.legend(loc='lower left')
plt.grid()
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# Your code here

# %%
fig, ax = plt.subplots(2,1, constrained_layout=True)
ax[0].plot(x, np.sin(x), color='blue', label='sin(x)')
ax[0].legend(loc='upper right')
ax[1].plot(x, np.cos(x), color='red', label='cos(x)')
ax[1].legend(loc='lower left')
fig.suptitle('Đồ thị hàm sin(x) và cos(x)')
plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# Your code here

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'])
y = np.array([23, 17, 9,8,7,6])
plt.bar(x, y)
plt.title('Mức độ phổ biến của các ngôn ngữ lập trình')
plt.xlabel('Programming Language')
plt.ylabel('Popylarity')
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# Your code here

# %%
label = np.array(['Python', 'Java', 'C++', 'C#', 'JavaScript', 'PHP'])
x = np.array([24.79, 31.27, 9.44, 10.85, 11.27, 12.39])
plt.pie(x, labels=label, autopct='%1.2f%%', shadow=True, explode=[0,0.1,0,0,0,0])
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# Your code here

# %%
from numpy import random
arr = random.normal(size=10000)
plt.hist(arr, bins=100)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# Your code here

# %%
arr = np.random.normal(size=10000)
plt.boxplot(arr)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# Your code here

# %%
arr = np.random.normal(size=10000)
fig, ax = plt.subplots(2,1, constrained_layout=True)
ax[0].hist(arr,bins=100, color='purple', edgecolor='white')
ax[0].set_title('Histogram')
ax[0].set_ylabel('Mật độ')
ax[1].boxplot(arr, vert=False)
ax[1].set_title('Boxplot')
fig.suptitle('Đồ thị hàm sin(x) và cos(x)')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
import pandas as pd
import seaborn as sb
tips = pd.read_csv('tips.csv')
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tipOfDay = tips.groupby('day')['tip'].sum().reset_index()
sb.barplot(x='day', y='tip', data=tipOfDay)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
tipTime = tips.groupby('time')['tip'].sum().reset_index()
sb.barplot(x='time', y='tip', data=tipTime)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
sb.displot(data=tips['total_bill'], kde=True)

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
sb.boxplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
sb.boxplot(x=tips['day'], y = tips['total_bill'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
sb.scatterplot(x=tips['total_bill'], y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sb.jointplot(x=tips['total_bill'], y=tips['tip'])

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sb.pairplot(data=tips)

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
plt.subplot(1,2,1)
sb.histplot(data=tips['total_bill'][tips.time=='Dinner'])
plt.subplot(1,2,2)
sb.histplot(data=tips['total_bill'][tips.time=='Lunch'])
plt.show()

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
plt.subplot(1,2,1)
sb.boxplot(y=tips['total_bill'][tips.time=='Dinner'])
plt.subplot(1,2,2)
sb.boxplot(y=tips['total_bill'][tips.time=='Lunch'])
plt.show()

# %% [markdown]
# ---
