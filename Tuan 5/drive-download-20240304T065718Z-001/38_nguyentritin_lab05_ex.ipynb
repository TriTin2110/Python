# %% [markdown]
# # Bài Tập

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
import numpy as np
import math
from scipy import stats as stats
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sample = []
for i in range(120, 200):
        sample.append(i)
MEDIUM_POP = np.random.choice(sample, size=10000, replace=True)
print(MEDIUM_POP)
print('-----------Câu a-----------')
mean_medium_pop = np.mean(MEDIUM_POP)
print('Chiều cao trung bình của quần thể:', mean_medium_pop)
std_medium_pop = np.std(MEDIUM_POP)
print('Độ lệch chuẩn chiều cao của quần thể:', std_medium_pop)

print('-----------Câu b-----------')
nguoi_cao = []
for i in MEDIUM_POP:
        if(i>=180):
                nguoi_cao.append(i)
print('Tỷ lệ người cao trong quần thể:', len(nguoi_cao)/len(MEDIUM_POP))

print('-----------Câu c-----------')
plt.hist(x=MEDIUM_POP, bins=100, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()

print('-----------Câu d-----------')
sample = np.random.normal(size=10000, scale=std_medium_pop, loc=mean_medium_pop)
plt.hist(x=sample, bins=100, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()
sb.kdeplot(data=sample)
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('Đồ thị hàm mật độ về chiều cao của quần thể')
plt.show()
# Out:
# [143 185 195 ... 131 127 179]
# -----------Câu a-----------
# Chiều cao trung bình của quần thể: 159.9048
# Độ lệch chuẩn chiều cao của quần thể: 23.099717248485966
# -----------Câu b-----------
# Tỷ lệ người cao trong quần thể: 0.2571
# -----------Câu c-----------
# -----------Câu d-----------

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
sample = []
for i in range(120, 200):
        sample.append(i)
SHORT_POP = np.random.choice(sample, size=20, replace=True)
print(SHORT_POP)
print('-----------Câu a-----------')
mean_short_pop = np.mean(SHORT_POP)
print('Chiều cao trung bình của quần thể:', mean_short_pop)
std_short_pop = np.std(SHORT_POP)
print('Độ lệch chuẩn chiều cao của quần thể:', std_short_pop)

print('-----------Câu b-----------')
nguoi_cao = []
for i in SHORT_POP:
        if(i>=180):
                nguoi_cao.append(i)
print('Tỷ lệ người cao trong quần thể:', len(nguoi_cao)/len(SHORT_POP))

print('-----------Câu c-----------')
plt.hist(x=SHORT_POP, bins=20, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()

print('-----------Câu d-----------')
sample = np.random.normal(size=10000, scale=std_short_pop, loc=mean_short_pop)
plt.hist(x=sample, bins=100, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()
sb.kdeplot(data=sample)
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('Đồ thị hàm mật độ về chiều cao của quần thể')
plt.show()
# Out:
# [133 168 148 166 142 137 181 182 154 171 174 189 188 151 167 151 188 167
#  154 190]
# -----------Câu a-----------
# Chiều cao trung bình của quần thể: 165.05
# Độ lệch chuẩn chiều cao của quần thể: 17.60532589871599
# -----------Câu b-----------
# Tỷ lệ người cao trong quần thể: 0.3
# -----------Câu c-----------
# -----------Câu d-----------

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
sample = []
for i in range(120, 200):
        sample.append(i)
MEDIUM_POP = np.random.choice(sample, size=100, replace=True)
print(MEDIUM_POP)
print('-----------Câu a-----------')
mean_medium_pop = np.mean(MEDIUM_POP)
print('Chiều cao trung bình của quần thể:', mean_medium_pop)
std_medium_pop = np.std(MEDIUM_POP)
print('Độ lệch chuẩn chiều cao của quần thể:', std_medium_pop)

print('-----------Câu b-----------')
nguoi_cao = []
for i in MEDIUM_POP:
        if(i>=180):
                nguoi_cao.append(i)
print('Tỷ lệ người cao trong quần thể:', len(nguoi_cao)/len(MEDIUM_POP))

print('-----------Câu c-----------')
plt.hist(x=MEDIUM_POP, bins=50, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()

print('-----------Câu d-----------')
sample = np.random.normal(size=10000, scale=std_medium_pop, loc=mean_medium_pop)
plt.hist(x=sample, bins=50, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('histogram về chiều cao của quần thể')
plt.show()
sb.kdeplot(data=sample)
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('Đồ thị hàm mật độ về chiều cao của quần thể')
plt.show()
# Out:
# [134 193 176 138 181 127 169 125 174 176 167 181 144 168 120 135 127 151
#  186 191 169 191 155 190 144 133 162 166 189 125 179 172 187 193 165 138
#  153 165 198 134 160 166 157 181 167 147 188 148 135 175 155 163 175 167
#  155 156 167 175 123 132 189 170 169 173 186 157 166 134 190 171 175 186
#  141 163 181 190 165 164 153 129 162 168 159 140 198 131 131 163 122 194
#  152 161 182 146 198 156 169 161 138 167]
# -----------Câu a-----------
# Chiều cao trung bình của quần thể: 162.13
# Độ lệch chuẩn chiều cao của quần thể: 20.692827259705233
# -----------Câu b-----------
# Tỷ lệ người cao trong quần thể: 0.23
# -----------Câu c-----------
# -----------Câu d-----------

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %%
result1 = []
sample = []
for i in range(120, 200):
        sample.append(i)
for i in range(0,100):
        SHORT_POP = np.random.choice(sample, size=20, replace=True)
        result1.append(np.mean(SHORT_POP))
plt.hist(x=result1, bins=20, edgecolor='white')
plt.xlabel('Trung bình mẫu')
plt.ylabel('Mật độ')
plt.show()

# %%
result2 = []
sample = []
for i in range(120, 200):
        sample.append(i)
for i in range(0,100):
        SHORT_POP = np.random.choice(sample, size=100, replace=True)
        result2.append(np.mean(SHORT_POP))
plt.hist(x=result2, bins=20, edgecolor='white')
plt.xlabel('Trung bình mẫu')
plt.ylabel('Mật độ')
plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(x=result1, bins=20, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('Kết quả a')
plt.subplot(1,2,2)
plt.hist(x=result2, bins=20, edgecolor='white')
plt.xlabel('Chiều cao')
plt.ylabel('Mật độ')
plt.title('Kết quả b')
plt.tight_layout()
plt.show()
print('Ta nhận ra rằng độ phân tán của kết quả a cao hơn so với kết quả b')
# Out:
# Ta nhận ra rằng độ phân tán của kết quả a cao hơn so với kết quả b

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %%
result = []
sample = []
nguoi_cao = []
for i in range(120, 200):
        sample.append(i)
for i in range(0,1000):
        SHORT_POP = np.random.choice(sample, size=100, replace=True)
        for i in SHORT_POP:
                if(i>=180):
                        nguoi_cao.append(i)

plt.hist(x=nguoi_cao, bins=20, edgecolor='white')
plt.xlabel('Tỷ lệ người cao')
plt.ylabel('Mật độ')
plt.show()

# %%
result = []
sample = []
nguoi_cao = []
for i in range(120, 200):
        sample.append(i)
for i in range(0,1000):
        SHORT_POP = np.random.choice(sample, size=500, replace=True)
        for i in SHORT_POP:
                if(i>=180):
                        nguoi_cao.append(i)

plt.hist(x=nguoi_cao, bins=20, edgecolor='white')
plt.xlabel('Tỷ lệ người cao')
plt.ylabel('Mật độ')
plt.show()

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %%
import math as ma
result = []
sample = []
for i in range(120, 200):
        sample.append(i)
for i in range(0,1000):
        SHORT_POP = np.random.choice(sample, size=100, replace=True)
        result.append(SHORT_POP)
phuong_sai = []
for i in result:
        phuong_sai.append(ma.pow(np.std(i), 2))
plt.hist(x=phuong_sai, bins=50, edgecolor='white')
plt.xlabel('Đại lượng phương sai')
plt.ylabel('Mật độ')
plt.show()

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$
